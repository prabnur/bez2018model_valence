# %%
from model.tone import generate_pure_tone

simp = generate_pure_tone(100)
comp = (generate_pure_tone(200) + generate_pure_tone(300) + generate_pure_tone(400) + generate_pure_tone(500)) / 4

CUTOFF = 2205 #0
simp = simp[:CUTOFF]
comp = comp[:CUTOFF]

# %%
from matplotlib.pyplot import plot

plot(simp)
plot(comp, color="red")
